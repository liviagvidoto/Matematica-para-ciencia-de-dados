# %%
## Regressão Polinomial para previsão de salários

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

# %%
#Carregando os dados
df = pd.read_csv('/home/livia/Downloads/Salary_Data.csv')

# %%
df.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
df.info
# Out:
# <bound method DataFrame.info of     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# ...

# %%
#Separando as variáveis
x = df[['YearsExperience']]
y = df['Salary']

# %%
#transformando em polinomial
poly = PolynomialFeatures(degree=2)
x_poly = poly.fit_transform(x)

# %%
#Treinando o modelo
model = LinearRegression()
model.fit(x_poly, y)
# Out:
# LinearRegression()

# %%
#Gerando a previsão
y_pred = model.predict(X_poly)

# %%
#Visualização
plt.scatter(X, y, color='blue')
plt.plot(X, y_pred, color='red')
plt.xlabel("Anos de Experiência")
plt.ylabel("Salário")
plt.title("Regressão Polinomial")
plt.show()

# %%
novo = np.array([[5]])
novo_poly = poly.transform(novo)
# Out:
# /home/livia/ambientes/jupyter/lib/python3.14/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(

# %%
previsao = model.predict(novo_poly)
print(f"Salário previsto: {previsao[0]:.2f}")
# Out:
# Salário previsto: 72921.17
